# %% [markdown]
# <a href="https://colab.research.google.com/github/kavyaagarwal178/plant_disease/blob/main/plant_disease.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# After executing the cell above, Drive
# files will be present in "/content/drive/My Drive".
# !ls "/content/drive/My Drive"
# Out:
#  Certificates  'Colab Notebooks'   Plant_images_pianalytix   test_data.csv   train_data.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.image import imread
import cv2
import random
import os
from os import listdir
from PIL import Image
from sklearn.preprocessing import label_binarize,  LabelBinarizer
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array, array_to_img
from keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dropout, Dense
from sklearn.model_selection import train_test_split
from keras.models import model_from_json
from keras.utils import to_categorical

# %%
# Plotting 12 images to check dataset
plt.figure(figsize=(12,12))
path = "/content/drive/My Drive/Plant_images_pianalytix/Potato___Early_blight"
for i in range(1,17):
    plt.subplot(4,4,i)
    plt.tight_layout()
    rand_img = imread(path +'/'+ random.choice(sorted(os.listdir(path))))
    plt.imshow(rand_img)
    plt.xlabel(rand_img.shape[1], fontsize = 10)#width of image
    plt.ylabel(rand_img.shape[0], fontsize = 10)#height of image

# %%
#Converting Images to array
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, (256,256))
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
dir = "/content/drive/My Drive/Plant_images_pianalytix"
root_dir = listdir(dir)
image_list, label_list = [], []
all_labels = ['Corn-Common_rust', 'Potato-Early_blight', 'Tomato-Bacterial_spot']
binary_labels = [0,1,2]
temp = -1

# Reading and converting image to numpy array
for directory in root_dir:
  plant_image_list = listdir(f"{dir}/{directory}")
  temp += 1
  for files in plant_image_list:
    image_path = f"{dir}/{directory}/{files}"
    image_list.append(convert_image_to_array(image_path))
    label_list.append(binary_labels[temp])

# %%
# Visualize the number of classes count
label_counts = pd.DataFrame(label_list).value_counts()
label_counts.head()
# Out:
# 0    300
# 1    300
# 2    300
# dtype: int64

# %%
image_list[0].shape
# Out:
# (256, 256, 3)

# %%
label_list = np.array(label_list)
label_list.shape
# Out:
# (900,)

# %%
x_train, x_test, y_train, y_test = train_test_split(image_list, label_list, test_size=0.2, random_state = 10)

# %%
x_train = np.array(x_train, dtype=np.float16) / 225.0
x_test = np.array(x_test, dtype=np.float16) / 225.0
x_train = x_train.reshape( -1, 256,256,3)
x_test = x_test.reshape( -1, 256,256,3)

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), padding="same",input_shape=(256,256,3), activation="relu"))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Conv2D(16, (3, 3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(8, activation="relu"))
model.add(Dense(3, activation="softmax"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 256, 256, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 85, 85, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 85, 85, 16)        4624
#
#  max_pooling2d_1 (MaxPoolin  (None, 42, 42, 16)        0
#  g2D)
#
#  flatten (Flatten)           (None, 28224)             0
#
#  dense (Dense)               (None, 8)                 225800
#
#  dense_1 (Dense)             (None, 3)                 27
#
# =================================================================
# Total params: 231347 (903.70 KB)
# Trainable params: 231347 (903.70 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss = 'categorical_crossentropy', optimizer = Adam(0.0001),metrics=['accuracy'])

# %%
# Splitting the training data set into training and validation data sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2)

# %%
# Training the model
epochs = 50
batch_size = 128
history = model.fit(x_train, y_train, batch_size = batch_size, epochs = epochs,
                    validation_data = (x_val, y_val))
# Out:
# Epoch 1/50
# 5/5 [==============================] - 41s 8s/step - loss: 1.0766 - accuracy: 0.3385 - val_loss: 0.9958 - val_accuracy: 0.6042
# Epoch 2/50
# 5/5 [==============================] - 39s 8s/step - loss: 0.9754 - accuracy: 0.6233 - val_loss: 0.9095 - val_accuracy: 0.6458
# Epoch 3/50
# 5/5 [==============================] - 36s 7s/step - loss: 0.8815 - accuracy: 0.6458 - val_loss: 0.8035 - val_accuracy: 0.6806
# Epoch 4/50
# 5/5 [==============================] - 37s 7s/step - loss: 0.7851 - accuracy: 0.6562 - val_loss: 0.7022 - val_accuracy: 0.6736
# Epoch 5/50
# 5/5 [==============================] - 39s 7s/step - loss: 0.6838 - accuracy: 0.6840 - val_loss: 0.6061 - val_accuracy: 0.8125
# Epoch 6/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.5854 - accuracy: 0.8438 - val_loss: 0.5127 - val_accuracy: 0.9653
# Epoch 7/50
# 5/5 [==============================] - 37s 8s/step - loss: 0.4945 - accuracy: 0.8976 - val_loss: 0.4286 - val_accuracy: 0.9861
# Epoch 8/50
# 5/5 [==============================] - 42s 9s/step - loss: 0.4118 - accuracy: 0.9722 - val_loss: 0.3677 - val_accuracy: 0.9583
# Epoch 9/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.3434 - accuracy: 0.9462 - val_loss: 0.3025 - val_accuracy: 0.9722
# Epoch 10/50
# 5/5 [==============================] - 39s 8s/step - loss: 0.2816 - accuracy: 0.9757 - val_loss: 0.2455 - val_accuracy: 0.9792
# Epoch 11/50
# 5/5 [==============================] - 39s 8s/step - loss: 0.2366 - accuracy: 0.9826 - val_loss: 0.2059 - val_accuracy: 0.9861
# Epoch 12/50
# 5/5 [==============================] - 37s 8s/step - loss: 0.1953 - accuracy: 0.9809 - val_loss: 0.1798 - val_accuracy: 0.9861
# Epoch 13/50
# 5/5 [==============================] - 36s 8s/step - loss: 0.1638 - accuracy: 0.9792 - val_loss: 0.1567 - val_accuracy: 0.9722
# Epoch 14/50
# 5/5 [==============================] - 37s 7s/step - loss: 0.1407 - accuracy: 0.9826 - val_loss: 0.1296 - val_accuracy: 0.9861
# Epoch 15/50
# 5/5 [==============================] - 48s 10s/step - loss: 0.1231 - accuracy: 0.9861 - val_loss: 0.1260 - val_accuracy: 0.9861
# Epoch 16/50
# 5/5 [==============================] - 36s 7s/step - loss: 0.1217 - accuracy: 0.9757 - val_loss: 0.1206 - val_accuracy: 0.9722
# Epoch 17/50
# 5/5 [==============================] - 42s 9s/step - loss: 0.1042 - accuracy: 0.9792 - val_loss: 0.0947 - val_accuracy: 0.9861
# Epoch 18/50
# 5/5 [==============================] - 36s 7s/step - loss: 0.0891 - accuracy: 0.9931 - val_loss: 0.0870 - val_accuracy: 0.9861
# Epoch 19/50
# 5/5 [==============================] - 36s 7s/step - loss: 0.0809 - accuracy: 0.9896 - val_loss: 0.0801 - val_accuracy: 0.9861
# Epoch 20/50
# 5/5 [==============================] - 36s 7s/step - loss: 0.0731 - accuracy: 0.9913 - val_loss: 0.0743 - val_accuracy: 0.9861
# Epoch 21/50
# 5/5 [==============================] - 36s 7s/step - loss: 0.0703 - accuracy: 0.9931 - val_loss: 0.0683 - val_accuracy: 0.9861
# Epoch 22/50
# 5/5 [==============================] - 35s 7s/step - loss: 0.0634 - accuracy: 0.9948 - val_loss: 0.0645 - val_accuracy: 0.9861
# Epoch 23/50
# 5/5 [==============================] - 38s 7s/step - loss: 0.0589 - accuracy: 0.9913 - val_loss: 0.0586 - val_accuracy: 0.9861
# Epoch 24/50
# 5/5 [==============================] - 36s 7s/step - loss: 0.0547 - accuracy: 0.9931 - val_loss: 0.0551 - val_accuracy: 0.9931
# Epoch 25/50
# 5/5 [==============================] - 36s 7s/step - loss: 0.0508 - accuracy: 0.9948 - val_loss: 0.0517 - val_accuracy: 0.9861
# Epoch 26/50
# 5/5 [==============================] - 36s 8s/step - loss: 0.0484 - accuracy: 0.9913 - val_loss: 0.0516 - val_accuracy: 0.9861
# Epoch 27/50
# 5/5 [==============================] - 36s 7s/step - loss: 0.0456 - accuracy: 0.9965 - val_loss: 0.0476 - val_accuracy: 0.9931
# Epoch 28/50
# 5/5 [==============================] - 35s 7s/step - loss: 0.0418 - accuracy: 0.9965 - val_loss: 0.0440 - val_accuracy: 0.9861
# Epoch 29/50
# 5/5 [==============================] - 38s 7s/step - loss: 0.0394 - accuracy: 0.9965 - val_loss: 0.0413 - val_accuracy: 0.9931
# Epoch 30/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.0379 - accuracy: 0.9948 - val_loss: 0.0417 - val_accuracy: 0.9861
# Epoch 31/50
# 5/5 [==============================] - 45s 10s/step - loss: 0.0366 - accuracy: 0.9965 - val_loss: 0.0391 - val_accuracy: 0.9931
# Epoch 32/50
# 5/5 [==============================] - 37s 7s/step - loss: 0.0363 - accuracy: 0.9948 - val_loss: 0.0405 - val_accuracy: 0.9861
# Epoch 33/50
# 5/5 [==============================] - 41s 9s/step - loss: 0.0341 - accuracy: 0.9965 - val_loss: 0.0377 - val_accuracy: 1.0000
# Epoch 34/50
# 5/5 [==============================] - 35s 7s/step - loss: 0.0342 - accuracy: 0.9983 - val_loss: 0.0365 - val_accuracy: 0.9861
# Epoch 35/50
# 5/5 [==============================] - 34s 7s/step - loss: 0.0308 - accuracy: 0.9983 - val_loss: 0.0332 - val_accuracy: 1.0000
# Epoch 36/50
# 5/5 [==============================] - 35s 7s/step - loss: 0.0269 - accuracy: 0.9983 - val_loss: 0.0323 - val_accuracy: 0.9861
# Epoch 37/50
# 5/5 [==============================] - 35s 7s/step - loss: 0.0263 - accuracy: 0.9965 - val_loss: 0.0294 - val_accuracy: 1.0000
# Epoch 38/50
# 5/5 [==============================] - 35s 7s/step - loss: 0.0255 - accuracy: 0.9983 - val_loss: 0.0268 - val_accuracy: 1.0000
# Epoch 39/50
# 5/5 [==============================] - 35s 7s/step - loss: 0.0246 - accuracy: 0.9965 - val_loss: 0.0251 - val_accuracy: 1.0000
# Epoch 40/50
# 5/5 [==============================] - 38s 7s/step - loss: 0.0216 - accuracy: 0.9983 - val_loss: 0.0243 - val_accuracy: 1.0000
# Epoch 41/50
# 5/5 [==============================] - 35s 7s/step - loss: 0.0210 - accuracy: 0.9983 - val_loss: 0.0241 - val_accuracy: 1.0000
# Epoch 42/50
# 5/5 [==============================] - 35s 7s/step - loss: 0.0210 - accuracy: 0.9983 - val_loss: 0.0239 - val_accuracy: 1.0000
# Epoch 43/50
# 5/5 [==============================] - 35s 7s/step - loss: 0.0199 - accuracy: 1.0000 - val_loss: 0.0218 - val_accuracy: 1.0000
# Epoch 44/50
# 5/5 [==============================] - 35s 7s/step - loss: 0.0192 - accuracy: 0.9983 - val_loss: 0.0203 - val_accuracy: 1.0000
# Epoch 45/50
# 5/5 [==============================] - 38s 8s/step - loss: 0.0251 - accuracy: 0.9983 - val_loss: 0.0196 - val_accuracy: 1.0000
# Epoch 46/50
# 5/5 [==============================] - 36s 7s/step - loss: 0.0285 - accuracy: 0.9913 - val_loss: 0.0272 - val_accuracy: 0.9931
# Epoch 47/50
# 5/5 [==============================] - 38s 7s/step - loss: 0.0293 - accuracy: 1.0000 - val_loss: 0.0201 - val_accuracy: 1.0000
# Epoch 48/50
# 5/5 [==============================] - 46s 10s/step - loss: 0.0272 - accuracy: 0.9948 - val_loss: 0.0194 - val_accuracy: 1.0000
# Epoch 49/50
# 5/5 [==============================] - 35s 7s/step - loss: 0.0210 - accuracy: 1.0000 - val_loss: 0.0172 - val_accuracy: 1.0000
# Epoch 50/50
# 5/5 [==============================] - 37s 7s/step - loss: 0.0176 - accuracy: 0.9965 - val_loss: 0.0168 - val_accuracy: 1.0000

# %%
model.save("/content/drive/My Drive/plant_disease.h5")
# serialize model to json
json_model = model.to_json()
#save the model architecture to JSON file
with open('/content/drive/My Drive/plant_model.json', 'w') as json_file:
    json_file.write(json_model)
#saving the weights of the model
model.save_weights('/content/drive/My Drive/plant_model_weights.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
#Plot the training history
plt.figure(figsize=(12, 5))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])

plt.show()

# %%
print("[INFO] Calculating model accuracy")
scores = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 6/6 [==============================] - 4s 619ms/step - loss: 0.0423 - accuracy: 0.9833
# Test Accuracy: 98.33333492279053

# %%
y_pred = model.predict(x_test)
# Out:
# 6/6 [==============================] - 3s 458ms/step

# %%
# Plotting image to compare
img = array_to_img(x_test[10])
img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
# Finding max value from predition list and comaparing original value vs predicted
print("Originally : ",all_labels[np.argmax(y_test[10])])
print("Predicted : ",all_labels[np.argmax(y_pred[10])])
# Out:
# Originally :  Potato-Early_blight
# Predicted :  Potato-Early_blight
